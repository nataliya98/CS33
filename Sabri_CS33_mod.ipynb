# %%
import pandas as pd
import numpy as np

# %%
times = pd.read_csv('timesData.csv')
shangai = pd.read_csv('shanghaiData.csv')
cwur = pd.read_csv('cwurData.csv')
attainment = pd.read_csv('educational_attainment_supplementary_data.csv')

# %%
attainment.head(5)
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# ...

# %% [markdown]
# Read the file educational_attainment_supplementary_data.csv, discarding any row with missing country_name or series_name

# %%
df1 = attainment.dropna(subset= ['country_name', 'series_name'])

# %%
df1
# Out:
#       country_name                                        series_name  1985  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54
# ...            ...                                                ...   ...
# 79045     Zimbabwe  UIS: Percentage of population age 25+ with som...   NaN
# 79046     Zimbabwe  UIS: Percentage of population age 25+ with som...   NaN
# 79047     Zimbabwe  UIS: Percentage of population age 25+ with unk...   NaN
# 79048     Zimbabwe  UIS: Percentage of population age 25+ with unk...   NaN
# 79049     Zimbabwe  UIS: Percentage of population age 25+ with unk...   NaN
#
# ...

# %%
df1['country_name'].isnull().sum()
# Out:
# 0

# %%
df1['series_name'].isnull().sum()
# Out:
# 0

# %%
anni= list(attainment.columns)
del anni[0:2]
anni
# Out:
# ['1985',
#  '1986',
#  '1987',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2015']

# %%
#indice = ['1985', '1986', '1987', '1990', '1991',
   #    '1992', '1993', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
    #   '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
     #  '2011', '2012', '2013', '2015']

# %%
dataframe1= pd.melt(df1, id_vars=['country_name','series_name'], value_vars=anni,var_name='year').dropna(subset= ['year', 'value'])
dataframe1
# Out:
#                country_name  \
# 0               Afghanistan
# 1               Afghanistan
# 2               Afghanistan
# 3               Afghanistan
# 4               Afghanistan
# ...                     ...
# 2054020  West Bank and Gaza
# 2054021  West Bank and Gaza
# 2054022  West Bank and Gaza
# 2054023  West Bank and Gaza
# 2054024  West Bank and Gaza
#
#                                                series_name  year    value
# 0        Barro-Lee: Average years of primary schooling,...  1985  0.33000
# 1        Barro-Lee: Average years of primary schooling,...  1985  1.03000
# 2        Barro-Lee: Average years of primary schooling,...  1985  0.83000
# 3        Barro-Lee: Average years of primary schooling,...  1985  2.34000
# 4        Barro-Lee: Average years of primary schooling,...  1985  0.54000
# ...                                                    ...   ...      ...
# 2054020  UIS: Percentage of population age 25+ with som...  2013  1.48356
# ...

# %%
my_baby = pd.DataFrame(columns = ['country_name', 'series_name', 'year', 'value'])
my_baby
# Out:
# Empty DataFrame
# Columns: [country_name, series_name, year, value]
# Index: []

# %%
riga1 = df1.iloc[0]
riga1
# Out:
# country_name                                          Afghanistan
# series_name     Barro-Lee: Average years of primary schooling,...
# 1985                                                         0.33
# 1986                                                          NaN
# 1987                                                          NaN
# 1990                                                         0.44
# 1991                                                          NaN
# 1992                                                          NaN
# 1993                                                          NaN
# 1995                                                         0.57
# 1996                                                          NaN
# 1997                                                          NaN
# 1998                                                          NaN
# 1999                                                          NaN
# ...

# %%
riga1['1986']
# Out:
# nan

# %%
pd.isna(riga1['1986'])
# Out:
# True

# %%
if not pd.isna(riga1['1986']):
    print ('True')
else:
    print('False')
# Out:
# False

# %%
def my_precious(riga):
    a = riga1['country_name']
    b = riga1['series_name']
    for i in indice:
        if not pd.isna(riga1[i]):
            e = riga1[i]
            dfx = pd.Series([a, b, i, e], index = ['country_name', 'series_name', 'year', 'value'])
            df_lenght = len(my_baby)
            my_baby.loc[df_lenght] = dfx
    return my_baby

# %%
my_baby
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78116 entries, 0 to 78115
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  78116 non-null  object
#  1   series_name   78116 non-null  object
#  2   year          78116 non-null  object
#  3   value         78116 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 3.0+ MB

# %%
def my_precious(riga):
    a = riga['country_name']
    b = riga['series_name']
    for i in indice:
        if not pd.isna(riga[i]):
            e = riga[i]
            dfx = pd.Series([a, b, i, e], index = ['country_name', 'series_name', 'year', 'value'])
            df_lenght = len(my_baby)
            my_baby.loc[df_lenght] = dfx
    return my_baby

# %%
my_precious(df1.iloc[9000])
# Out:
#       country_name                                        series_name  year  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...  1985
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...  1990
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...  1995
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...  2000
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...  2005
# ...            ...                                                ...   ...
# 78111    Argentina  Barro-Lee: Percentage of population age 55-59 ...  1990
# 78112    Argentina  Barro-Lee: Percentage of population age 55-59 ...  1995
# 78113    Argentina  Barro-Lee: Percentage of population age 55-59 ...  2000
# 78114    Argentina  Barro-Lee: Percentage of population age 55-59 ...  2005
# 78115    Argentina  Barro-Lee: Percentage of population age 55-59 ...  2010
#
#        value
# 0       0.33
# 1       0.44
# ...

# %%
df1.apply(my_precious, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-29538dae7560> in <module>
# ----> 1 df1.apply(my_precious, axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     311
#     312         # compute the result using the series generator
# --> 313         results, res_index = self.apply_series_generator()
#     314
# ...

# %% [markdown]
# ## 10. For each university, find the number of rankings in which they appear (it suffices to appear in one year for each ranking).

# %%
rank1 = pd.DataFrame(cwur.groupby('institution', as_index = False).count()[['institution','year']])
rank1['cwur'] = 1
rank1
# Out:
#                                    institution  year  cwur
# 0     AGH University of Science and Technology     2     1
# 1                           Aalborg University     2     1
# 2                             Aalto University     2     1
# 3                            Aarhus University     2     1
# 4                       Aberystwyth University     2     1
# ...                                        ...   ...   ...
# 1019                    École centrale de Lyon     1     1
# 1020          École normale supérieure - Paris     4     1
# 1021        École normale supérieure de Cachan     1     1
# 1022          École normale supérieure de Lyon     2     1
# 1023                         Örebro University     2     1
#
# [1024 rows x 3 columns]

# %%
rank2 = pd.DataFrame(shangai.groupby('university_name', as_index = False).count()[['university_name','year']])
rank2['shangai'] = 1
rank2
# Out:
#               university_name  year  shangai
# 0          Aalborg University     2        1
# 1            Aalto University     7        1
# 2           Aarhus University    11        1
# 3    Aix Marseille University     3        1
# 4    Aix-Marseille University     1        1
# ..                        ...   ...      ...
# 653      Yamaguchi University     7        1
# 654        Yeshiva University     9        1
# 655         Yonsei University     9        1
# 656           York University     7        1
# 657       Zhejiang University    10        1
#
# [658 rows x 3 columns]

# %%
rank3 = pd.DataFrame(times.groupby('university_name', as_index = False).count()[['university_name','year']])
rank3['times'] = 1
rank3
# Out:
#                               university_name  year  times
# 0    AGH University of Science and Technology     1      1
# 1                          Aalborg University     5      1
# 2                            Aalto University     5      1
# 3                           Aarhus University     6      1
# 4                      Aberystwyth University     5      1
# ..                                        ...   ...    ...
# 813                  École Normale Supérieure     6      1
# 814          École Normale Supérieure de Lyon     6      1
# 815                       École Polytechnique     6      1
# 816  École Polytechnique Fédérale de Lausanne     6      1
# 817                         Örebro University     1      1
#
# [818 rows x 3 columns]

# %%
rank12 = pd.merge(rank1, rank2, left_on = 'institution', right_on = 'university_name', how = 'outer')
rank123 = pd.merge(rank12, rank3, left_on = 'institution', right_on = 'university_name', how = 'outer')
rank123
# Out:
#                                    institution  year_x  cwur  \
# 0     AGH University of Science and Technology     2.0   1.0
# 1                           Aalborg University     2.0   1.0
# 2                             Aalto University     2.0   1.0
# 3                            Aarhus University     2.0   1.0
# 4                       Aberystwyth University     2.0   1.0
# ...                                        ...     ...   ...
# 1469                                       NaN     NaN   NaN
# 1470                                       NaN     NaN   NaN
# 1471                                       NaN     NaN   NaN
# 1472                                       NaN     NaN   NaN
# 1473                                       NaN     NaN   NaN
#
#        university_name_x  year_y  shangai  \
# 0                    NaN     NaN      NaN
# 1     Aalborg University     2.0      1.0
# 2       Aalto University     7.0      1.0
# 3      Aarhus University    11.0      1.0
# ...

# %%
rank123['cwur'].replace(np.nan, 0, inplace=True)
rank123['shangai'].replace(np.nan, 0, inplace=True)
rank123['times'].replace(np.nan, 0, inplace=True)
rank123
# Out:
#                                    institution  year_x  cwur  \
# 0     AGH University of Science and Technology     2.0   1.0
# 1                           Aalborg University     2.0   1.0
# 2                             Aalto University     2.0   1.0
# 3                            Aarhus University     2.0   1.0
# 4                       Aberystwyth University     2.0   1.0
# ...                                        ...     ...   ...
# 1469                                       NaN     NaN   0.0
# 1470                                       NaN     NaN   0.0
# 1471                                       NaN     NaN   0.0
# 1472                                       NaN     NaN   0.0
# 1473                                       NaN     NaN   0.0
#
#        university_name_x  year_y  shangai  \
# 0                    NaN     NaN      0.0
# 1     Aalborg University     2.0      1.0
# 2       Aalto University     7.0      1.0
# 3      Aarhus University    11.0      1.0
# ...

# %%
rank123['numer_rank'] = rank123['cwur'] + rank123['shangai'] + rank123['times']
rank123
# Out:
#                                    institution  year_x  cwur  \
# 0     AGH University of Science and Technology     2.0   1.0
# 1                           Aalborg University     2.0   1.0
# 2                             Aalto University     2.0   1.0
# 3                            Aarhus University     2.0   1.0
# 4                       Aberystwyth University     2.0   1.0
# ...                                        ...     ...   ...
# 1469                                       NaN     NaN   0.0
# 1470                                       NaN     NaN   0.0
# 1471                                       NaN     NaN   0.0
# 1472                                       NaN     NaN   0.0
# 1473                                       NaN     NaN   0.0
#
#        university_name_x  year_y  shangai  \
# 0                    NaN     NaN      0.0
# 1     Aalborg University     2.0      1.0
# 2       Aalto University     7.0      1.0
# 3      Aarhus University    11.0      1.0
# ...
