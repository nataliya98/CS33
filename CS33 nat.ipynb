# %%
import pandas as pd
import re
import numpy as np

# %%
times = pd.read_csv('timesData.csv', sep= ',')
shangai = pd.read_csv('shanghaiData.csv')
cwur = pd.read_csv('cwurData.csv')

# %% [markdown]
# ## 1. For each university, extract from the times dataset the most recent and the least recent data, obtaining two separate dataframes

# %%
times.head(20)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations  income total_score  \
# 0      99.7          72.4      98.7       98.8    34.5        96.1
# 1      97.7          54.6      98.0       99.9    83.7        96.0
# 2      97.8          82.3      91.4       99.9    87.5        95.6
# 3      98.3          29.5      98.1       99.2    64.3        94.3
# 4      90.9          70.3      95.4       99.9     NaN        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
dataframe1 = times.groupby('university_name', as_index=False)['year'].max()
dataframe1
# Out:
#                               university_name  year
# 0    AGH University of Science and Technology  2016
# 1                          Aalborg University  2016
# 2                            Aalto University  2016
# 3                           Aarhus University  2016
# 4                      Aberystwyth University  2016
# ..                                        ...   ...
# 813                  École Normale Supérieure  2016
# 814          École Normale Supérieure de Lyon  2016
# 815                       École Polytechnique  2016
# 816  École Polytechnique Fédérale de Lausanne  2016
# 817                         Örebro University  2016
#
# [818 rows x 2 columns]

# %%
dataframe2 = times.groupby('university_name', as_index= False)['year'].min()
dataframe2
# Out:
#                               university_name  year
# 0    AGH University of Science and Technology  2016
# 1                          Aalborg University  2012
# 2                            Aalto University  2012
# 3                           Aarhus University  2011
# 4                      Aberystwyth University  2012
# ..                                        ...   ...
# 813                  École Normale Supérieure  2011
# 814          École Normale Supérieure de Lyon  2011
# 815                       École Polytechnique  2011
# 816  École Polytechnique Fédérale de Lausanne  2011
# 817                         Örebro University  2016
#
# [818 rows x 2 columns]

# %% [markdown]
# ## 2. For each university, compute the improvement in income between the least recent and the most recent data points

# %%
times['income']= times['income'].apply(pd.to_numeric, errors= 'coerce')

# %%
df= times.groupby('university_name')[['income','year']].max()
df
# Out:
#                                           income  year
# university_name
# AGH University of Science and Technology     NaN  2016
# Aalborg University                          43.9  2016
# Aalto University                            73.7  2016
# Aarhus University                           69.7  2016
# Aberystwyth University                      35.5  2016
# ...                                          ...   ...
# École Normale Supérieure                    47.2  2016
# École Normale Supérieure de Lyon            31.7  2016
# École Polytechnique                         82.3  2016
# École Polytechnique Fédérale de Lausanne    65.4  2016
# Örebro University                           29.8  2016
#
# [818 rows x 2 columns]

# %%
df2= times.groupby('university_name')[['income','year']].min()
df2
# Out:
#                                           income  year
# university_name
# AGH University of Science and Technology     NaN  2016
# Aalborg University                          36.4  2012
# Aalto University                            39.4  2012
# Aarhus University                           59.8  2011
# Aberystwyth University                      31.3  2012
# ...                                          ...   ...
# École Normale Supérieure                    30.7  2011
# École Normale Supérieure de Lyon            25.1  2011
# École Polytechnique                         63.0  2011
# École Polytechnique Fédérale de Lausanne    38.0  2011
# Örebro University                           29.8  2016
#
# [818 rows x 2 columns]

# %%
df3 = pd.merge(df, df2, on= 'university_name')
df3.head(20)
# Out:
#                                           income_x  year_x  income_y  year_y
# university_name
# AGH University of Science and Technology       NaN    2016       NaN    2016
# Aalborg University                            43.9    2016      36.4    2012
# Aalto University                              73.7    2016      39.4    2012
# Aarhus University                             69.7    2016      59.8    2011
# Aberystwyth University                        35.5    2016      31.3    2012
# Adam Mickiewicz University                    28.7    2016      28.7    2016
# Aix-Marseille University                      33.1    2016      33.1    2016
# Ajou University                               45.7    2016      45.7    2016
# Alexandria University                         36.0    2016      29.7    2011
# Alexandru Ioan Cuza University                28.2    2016      28.2    2016
# Aligarh Muslim University                     29.6    2016      29.6    2016
# ...

# %%
df3['improvement'] = df3['income_x'] - df3['income_y']
df3
# Out:
#                                           income_x  year_x  income_y  year_y  \
# university_name
# AGH University of Science and Technology       NaN    2016       NaN    2016
# Aalborg University                            43.9    2016      36.4    2012
# Aalto University                              73.7    2016      39.4    2012
# Aarhus University                             69.7    2016      59.8    2011
# Aberystwyth University                        35.5    2016      31.3    2012
# ...                                            ...     ...       ...     ...
# École Normale Supérieure                      47.2    2016      30.7    2011
# École Normale Supérieure de Lyon              31.7    2016      25.1    2011
# École Polytechnique                           82.3    2016      63.0    2011
# École Polytechnique Fédérale de Lausanne      65.4    2016      38.0    2011
# Örebro University                             29.8    2016      29.8    2016
#
# ...

# %% [markdown]
# ## 3. Find the university with the largest increase computed in the previous point

# %%
df3[df3['improvement']== df3['improvement'].max()]
# Out:
#                  income_x  year_x  income_y  year_y  increasing2  improvement
# university_name
# TU Dresden           99.7    2016      31.9    2012         67.8         67.8

# %% [markdown]
# ## 4. For each ranking, consider only the most recent data point. For each university, compute the maximum difference between the rankings (e.g. for Aarhus University the value is 122-73=49). Notice that some rankings are expressed as a range

# %%
times[times['university_name'] == 'Aarhus University']
# Out:
#      world_rank    university_name  country  teaching international  research  \
# 166         167  Aarhus University  Denmark      38.1          33.4      55.6
# 324         125  Aarhus University  Denmark      30.7          69.3      49.0
# 717         116  Aarhus University  Denmark      35.7          66.4      54.6
# 1139        138  Aarhus University  Denmark      30.7          67.2      46.4
# 1554        153  Aarhus University  Denmark      30.9          66.3      47.5
# 1908       =106  Aarhus University  Denmark      36.9          76.8      50.7
#
#       citations income total_score num_students  student_staff_ratio  \
# 166        57.3   61.5        49.9       23,895                 13.6
# 324        64.0   67.0        50.0       23,895                 13.6
# 717        71.6   69.7        55.3       23,895                 13.6
# 1139       65.8   67.5        49.6       23,895                 13.6
# 1554       66.5   59.8        49.9       23,895                 13.6
# ...

# %%
shangai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
shangai[shangai['university_name'] == 'Aarhus University']
# Out:
#      world_rank    university_name national_rank  total_score  alumni  award  \
# 100     101-152  Aarhus University             2          NaN    15.4   19.3
# 601     102-150  Aarhus University             2          NaN    14.8   18.9
# 1101    102-150  Aarhus University             2          NaN    14.4   18.9
# 1603         93  Aarhus University             2         24.5    13.7   18.9
# 2109         97  Aarhus University             2         24.2    13.4   18.9
# 2611         98  Aarhus University             2         24.2    13.1   18.9
# 3099         86  Aarhus University             2         25.4    13.2   22.1
# 3599         86  Aarhus University             2         25.5    12.1   22.8
# 3878         81  Aarhus University           2.0         26.0    12.0   22.2
# 3970         74  Aarhus University             2         27.4    11.8   22.1
# 4469         73  Aarhus University             2         27.3    11.5   22.1
#
#       hici    ns   pub   pcp  year
# ...

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
cwur[cwur['institution'] == 'Aarhus University']
# Out:
#       world_rank        institution  country  national_rank  \
# 318          119  Aarhus University  Denmark              2
# 1321         122  Aarhus University  Denmark              2
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 318                    292                188                 107
# 1321                   310                165                 106
#
#       publications  influence  citations  broad_impact  patents  score  year
# 318             90         78         81          90.0      194  50.17  2014
# 1321            91         81        101          95.0      154  49.65  2015

# %% [markdown]
# ## 5. Consider only the most recent data point of the "times" dataset. Compute the number of male and female students for each country.

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
ratio = re.compile('\d')

# %%
times['female_male_ratio'] = times['female_male_ratio'].astype(str)

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
times['female']= times['female_male_ratio'].str.extract('(\d+)')
times['female'] =times['female'].astype(float)

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
country = times.groupby('country')[['year','num_students','female']].max()
country
# Out:
#                            year num_students female
# country
# Argentina                  2016      108,373     62
# Australia                  2016        9,026    NaN
# Austria                    2016        7,542     67
# Bangladesh                 2016       62,716     34
# Belarus                    2016       29,303     69
# ...                         ...          ...    ...
# Unisted States of America  2016          NaN    NaN
# United Arab Emirates       2016        9,221     76
# United Kingdom             2016          NaN    NaN
# United States of America   2016          NaN    NaN
# Unted Kingdom              2016          NaN    NaN
#
# [72 rows x 3 columns]

# %%
country['num_students'] =country['num_students'].astype(str)

# %%
country['num_students'] =country['num_students'].str.replace(',',"")
country
# Out:
#                            year num_students female
# country
# Argentina                  2016       108373     62
# Australia                  2016         9026    NaN
# Austria                    2016         7542     67
# Bangladesh                 2016        62716     34
# Belarus                    2016        29303     69
# ...                         ...          ...    ...
# Unisted States of America  2016          nan    NaN
# United Arab Emirates       2016         9221     76
# United Kingdom             2016          nan    NaN
# United States of America   2016          nan    NaN
# Unted Kingdom              2016          nan    NaN
#
# [72 rows x 3 columns]

# %%
country['num_students'] =country['num_students'].astype(float)

# %%
country['female']= country['female'].astype(float)

# %%
country
# Out:
#                            year  num_students  female
# country
# Argentina                  2016      108373.0    62.0
# Australia                  2016        9026.0     NaN
# Austria                    2016        7542.0    67.0
# Bangladesh                 2016       62716.0    34.0
# Belarus                    2016       29303.0    69.0
# ...                         ...           ...     ...
# Unisted States of America  2016           NaN     NaN
# United Arab Emirates       2016        9221.0    76.0
# United Kingdom             2016           NaN     NaN
# United States of America   2016           NaN     NaN
# Unted Kingdom              2016           NaN     NaN
#
# [72 rows x 3 columns]

# %%
country['female_stud'] = country['num_students'] *(country['female']/100)

# %%
country
# Out:
#                            year  num_students  female  female_stud
# country
# Argentina                  2016      108373.0    62.0     67191.26
# Australia                  2016        9026.0     NaN          NaN
# Austria                    2016        7542.0    67.0      5053.14
# Bangladesh                 2016       62716.0    34.0     21323.44
# Belarus                    2016       29303.0    69.0     20219.07
# ...                         ...           ...     ...          ...
# Unisted States of America  2016           NaN     NaN          NaN
# United Arab Emirates       2016        9221.0    76.0      7007.96
# United Kingdom             2016           NaN     NaN          NaN
# United States of America   2016           NaN     NaN          NaN
# Unted Kingdom              2016           NaN     NaN          NaN
#
# [72 rows x 4 columns]

# %%
country['male_stud'] = country['num_students'] *(1-country['female']/100)

# %%
country
# Out:
#                            year  num_students  female  female_stud  male_stud
# country
# Argentina                  2016      108373.0    62.0     67191.26   41181.74
# Australia                  2016        9026.0     NaN          NaN        NaN
# Austria                    2016        7542.0    67.0      5053.14    2488.86
# Bangladesh                 2016       62716.0    34.0     21323.44   41392.56
# Belarus                    2016       29303.0    69.0     20219.07    9083.93
# ...                         ...           ...     ...          ...        ...
# Unisted States of America  2016           NaN     NaN          NaN        NaN
# United Arab Emirates       2016        9221.0    76.0      7007.96    2213.04
# United Kingdom             2016           NaN     NaN          NaN        NaN
# United States of America   2016           NaN     NaN          NaN        NaN
# Unted Kingdom              2016           NaN     NaN          NaN        NaN
#
# [72 rows x 5 columns]

# %% [markdown]
# ## 6. Find the universities where the ratio between female and male is below the average ratio (computed over all universities)

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
times['ratio'] = (times['female']/100)/(1-times['female']/100)
times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
times[times['ratio']== np.inf]
# Out:
#      world_rank         university_name      country  teaching international  \
# 1760    351-400  Ewha Womans University  South Korea      23.5          36.0
# 2227    401-500  Ewha Womans University  South Korea      23.9          34.3
#
#       research  citations income total_score num_students  \
# 1760      18.0       57.6   61.3           -       17,625
# 2227      18.3       50.4   57.6           -       17,625
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 1760                 14.4                     6%           100 : 0  2015
# 2227                 14.4                     6%           100 : 0  2016
#
#       female  ratio
# 1760   100.0    inf
# 2227   100.0    inf

# %%
times['ratio'].replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
times[times['ratio']== np.inf]
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, country, teaching, international, research, citations, income, total_score, num_students, student_staff_ratio, international_students, female_male_ratio, year, female, ratio]
# Index: []

# %%
ratio= times['ratio'].mean()
ratio
# Out:
# 1.0684463755952165

# %%
university_ratio=times[times['ratio']<=ratio]
university_ratio
# Out:
#      world_rank                        university_name  \
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# 5             6                University of Cambridge
# ...         ...                                    ...
# 2597    601-800                      Xidian University
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# ...

# %%
university_ratio['university_name'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 1          California Institute of Technology
# 2       Massachusetts Institute of Technology
# 3                         Stanford University
# 4                        Princeton University
# 5                     University of Cambridge
#                         ...
# 2597                        Xidian University
# 2598                      Yeungnam University
# 2599              Yıldız Technical University
# 2601             Yokohama National University
# 2602                       Yuan Ze University
# Name: university_name, Length: 1078, dtype: object>
