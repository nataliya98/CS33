# %%
import pandas as pd

# %%
times = pd.read_csv('timesData.csv')
shangai = pd.read_csv('shanghaiData.csv')
cwur = pd.read_csv('cwurData.csv')

# %%
times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
len(times['world_rank'].unique())
# Out:
# 250

# %%
dataframe1 = times.groupby('university_name', as_index=False)['year'].max()
dataframe1
# Out:
#                               university_name  year
# 0    AGH University of Science and Technology  2016
# 1                          Aalborg University  2016
# 2                            Aalto University  2016
# 3                           Aarhus University  2016
# 4                      Aberystwyth University  2016
# ..                                        ...   ...
# 813                  École Normale Supérieure  2016
# 814          École Normale Supérieure de Lyon  2016
# 815                       École Polytechnique  2016
# 816  École Polytechnique Fédérale de Lausanne  2016
# 817                         Örebro University  2016
#
# [818 rows x 2 columns]

# %%
dataframe2 = times.groupby('university_name', as_index= False)['year'].min()
dataframe2
# Out:
#                               university_name  year
# 0    AGH University of Science and Technology  2016
# 1                          Aalborg University  2012
# 2                            Aalto University  2012
# 3                           Aarhus University  2011
# 4                      Aberystwyth University  2012
# ..                                        ...   ...
# 813                  École Normale Supérieure  2011
# 814          École Normale Supérieure de Lyon  2011
# 815                       École Polytechnique  2011
# 816  École Polytechnique Fédérale de Lausanne  2011
# 817                         Örebro University  2016
#
# [818 rows x 2 columns]

# %%
 dfmax = times.loc[times.groupby('university_name')['year'].idxmax()]
dfmax
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
# ...         ...                                       ...             ...
# 1856         54                  École Normale Supérieure          France
# 2013    201-250          École Normale Supérieure de Lyon          France
# 1904       =101                       École Polytechnique          France
# 1833         31  École Polytechnique Fédérale de Lausanne     Switzerland
# 2134    301-350                         Örebro University          Sweden
#
#       teaching international  research  citations income total_score  \
# ...

# %%
 dfmin = times.loc[times.groupby('university_name')['year'].idxmin()]
dfmin
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
# ...         ...                                       ...             ...
# 41           42                  École Normale Supérieure          France
# 99          100          École Normale Supérieure de Lyon          France
# 38           39                       École Polytechnique          France
# 47           48  École Polytechnique Fédérale de Lausanne     Switzerland
# 2134    301-350                         Örebro University          Sweden
#
#       teaching international  research  citations income total_score  \
# ...

# %%
dfmax
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
times[times['university_name'] == 'Aarhus University']
# Out:
#      world_rank    university_name  country  teaching international  research  \
# 166         167  Aarhus University  Denmark      38.1          33.4      55.6
# 324         125  Aarhus University  Denmark      30.7          69.3      49.0
# 717         116  Aarhus University  Denmark      35.7          66.4      54.6
# 1139        138  Aarhus University  Denmark      30.7          67.2      46.4
# 1554        153  Aarhus University  Denmark      30.9          66.3      47.5
# 1908       =106  Aarhus University  Denmark      36.9          76.8      50.7
#
#       citations income total_score num_students  student_staff_ratio  \
# 166        57.3   61.5        49.9       23,895                 13.6
# 324        64.0   67.0        50.0       23,895                 13.6
# 717        71.6   69.7        55.3       23,895                 13.6
# 1139       65.8   67.5        49.6       23,895                 13.6
# 1554       66.5   59.8        49.9       23,895                 13.6
# ...

# %%
shangai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
shangai[shangai['university_name'] == 'Aarhus University']
# Out:
#      world_rank    university_name national_rank  total_score  alumni  award  \
# 100     101-152  Aarhus University             2          NaN    15.4   19.3
# 601     102-150  Aarhus University             2          NaN    14.8   18.9
# 1101    102-150  Aarhus University             2          NaN    14.4   18.9
# 1603         93  Aarhus University             2         24.5    13.7   18.9
# 2109         97  Aarhus University             2         24.2    13.4   18.9
# 2611         98  Aarhus University             2         24.2    13.1   18.9
# 3099         86  Aarhus University             2         25.4    13.2   22.1
# 3599         86  Aarhus University             2         25.5    12.1   22.8
# 3878         81  Aarhus University           2.0         26.0    12.0   22.2
# 3970         74  Aarhus University             2         27.4    11.8   22.1
# 4469         73  Aarhus University             2         27.3    11.5   22.1
#
#       hici    ns   pub   pcp  year
# ...

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
cwur[cwur['institution'] == 'Aarhus University']
# Out:
#       world_rank        institution  country  national_rank  \
# 318          119  Aarhus University  Denmark              2
# 1321         122  Aarhus University  Denmark              2
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 318                    292                188                 107
# 1321                   310                165                 106
#
#       publications  influence  citations  broad_impact  patents  score  year
# 318             90         78         81          90.0      194  50.17  2014
# 1321            91         81        101          95.0      154  49.65  2015
