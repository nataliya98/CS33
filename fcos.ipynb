# %%
import pandas as pd

# %%
times = pd.read_csv('/Users/hellemalexandracarrascogarcia/Downloads/timesData.csv')
shangai = pd.read_csv('/Users/hellemalexandracarrascogarcia/Downloads/shanghaiData.csv')
cwur = pd.read_csv('/Users/hellemalexandracarrascogarcia/Downloads/cwurData.csv')

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
shangai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# ## 11. In the times ranking, compute the number of times each university appears

# %%
dataframe11=pd.DataFrame(columns=['count'])
dataframe11['count']=times.groupby('university_name', as_index=False).size()
dataframe11
# Out:
#                                           count
# university_name
# AGH University of Science and Technology      1
# Aalborg University                            5
# Aalto University                              5
# Aarhus University                             6
# Aberystwyth University                        5
# ...                                         ...
# École Normale Supérieure                      6
# École Normale Supérieure de Lyon              6
# École Polytechnique                           6
# École Polytechnique Fédérale de Lausanne      6
# Örebro University                             1
#
# [818 rows x 1 columns]

# %% [markdown]
# shangai.head()

# %% [markdown]
# ##  12. Find the universities that appear at most twice in the times ranking

# %%
dataframe12=dataframe11[dataframe11['count']>=2]
dataframe12.head()
# Out:
#                         count
# university_name
# Aalborg University          5
# Aalto University            5
# Aarhus University           6
# Aberystwyth University      5
# Alexandria University       3

# %% [markdown]
# ## 13. The universities that, in any year, have the same position in all three rankings (they must have the same position in a year).

# %%
shangai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
cwur=cwur.rename(columns={"institution":"university_name"})
cwur.head()
# Out:
#    world_rank                        university_name         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
merged=pd.merge(times[['world_rank', 'university_name']],shangai,cwur,on=['world_rank'])
merged.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b8db6c044826> in <module>
# ----> 1 merged=pd.merge(times[['world_rank', 'university_name']],shangai,cwur,on=['world_rank'])
#       2 merged.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in get_result(self)
# ...

# %%
merged
# Out:
#    world_rank                             university_name  year national_rank  \
# 0           1                          Harvard University  2011             1
# 1          11                             Yale University  2012             9
# 2          11                             Yale University  2013           9.0
# 3          11                             Yale University  2014             9
# 4          12       University of California, Los Angeles  2014            10
# 5          12       University of California, Los Angeles  2015            10
# 6          15                  University of Pennsylvania  2013          13.0
# 7          16                  University of Pennsylvania  2014            14
# 8           2                         Stanford University  2012             2
# 9           2                         Stanford University  2013           2.0
# 10         29  University of Illinois at Urbana-Champaign  2015            21
# ...

# %%
merged = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
merged1 = pd.merge(merged,cwur,on=['world_rank','university_name','year'], sort=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9ce63a0c47da> in <module>
#       1 merged = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
# ----> 2 merged1 = pd.merge(merged,cwur,on=['world_rank','university_name','year'], sort=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
merged = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
merged1 = pd.merge(merged, cwur, left_on=['world_rank','university_name','year'], right_on=['world_rank','institution','year'])
merged1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-bbd7bb05d16a> in <module>
#       1 merged = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
# ----> 2 merged1 = pd.merge(merged, cwur, left_on=['world_rank','university_name','year'], right_on=['world_rank','institution','year'])
#       3 merged1
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ...

# %%
merge = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
cwur=cwur.rename(columns={"institution":"university_name"})
merge1= pd.merge(merge,cwur,on=['world_rank'], sort=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-226-21530664cafc> in <module>
#       1 merge = pd.merge(times[['world_rank','university_name','year']],shangai,on=['world_rank','university_name','year'], sort=True)
#       2 cwur=cwur.rename(columns={"institution":"university_name"})
# ----> 3 merge1= pd.merge(merge,cwur,on=['world_rank'], sort=True)
#       4
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ...
